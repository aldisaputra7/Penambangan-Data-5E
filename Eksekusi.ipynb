# %%
import pandas as pd
from scipy import stats
import numpy as np
import seaborn as sns 
data = pd.read_csv("data.csv")
cm = sns.light_palette("white", as_cmap=True)
data.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow0_col0 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow0_col1 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow0_col2 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow0_col3 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow1_col0 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow1_col1 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow1_col2 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow1_col3 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow2_col0 {
#             background-color:  #fcfcfc;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow2_col1 {
#             background-color:  #f8f8f8;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow2_col2 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow2_col3 {
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow3_col0 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow3_col1 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow3_col2 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow3_col3 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow4_col0 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow4_col1 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow4_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow4_col3 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow5_col0 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow5_col1 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow5_col2 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow5_col3 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow6_col0 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow6_col1 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow6_col2 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow6_col3 {
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow7_col0 {
#             background-color:  #fefefe;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow7_col1 {
#             background-color:  #fefefe;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow7_col2 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow7_col3 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow8_col0 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow8_col1 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow8_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow8_col3 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow9_col0 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow9_col1 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow9_col2 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow9_col3 {
#             background-color:  #fbfbfb;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow10_col0 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow10_col1 {
#             background-color:  #fcfcfc;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow10_col2 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow10_col3 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow11_col0 {
#             background-color:  #fafafa;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow11_col1 {
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow11_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow11_col3 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow12_col0 {
#             background-color:  #ffffff;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow12_col1 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow12_col2 {
#             background-color:  #f4f4f4;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow12_col3 {
#             background-color:  #fcfcfc;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow13_col0 {
#             background-color:  #f3f3f3;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow13_col1 {
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow13_col2 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow13_col3 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow14_col0 {
#             background-color:  #f9f9f9;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow14_col1 {
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow14_col2 {
#             background-color:  #f5f5f5;
#             color:  #000000;
#         }    #T_ade84dca_cffb_11e9_95ac_c0b6f9e635fbrow14_col3 {
#             background-color:  #fdfdfd;

# %%
colum = data.columns.tolist()
for x in colum:
    ds=[x for x in data[x]]
    desc= data[x].describe()
    array= [x for x in desc]
    print("Detail kolom ",x)
    print("rata-rata: ",array[1])
    print("Median: ",np.median(np.array(ds)))
    print("Modus: ", stats.mode(ds))
    print("Standard deviasi: ",np.std(ds))
    print("varian: ", stats.variation(ds))
    print("Skewness: ",stats.skew(ds))
    print("Quartil 1: ",array[4])
    print("Quartil 2: ",array[5])
    print("Quartil 3: ",array[6])
    
    print("\n")
# Out:
# Detail kolom  KOPI
# rata-rata:  105.416
# Median:  106.0
# Modus:  ModeResult(mode=array([64]), count=array([11]))
# Standard deviasi:  27.12111620121856
# varian:  0.25727703765290433
# Skewness:  -0.02099108069384586
# Quartil 1:  80.0
# Quartil 2:  106.0
# Quartil 3:  130.0
#
#
# Detail kolom  ES TEH
# rata-rata:  106.532
# Median:  108.0
# Modus:  ModeResult(mode=array([145]), count=array([13]))
# Standard deviasi:  26.43280113798006
# varian:  0.24812076313201725
# Skewness:  -0.10272439817862315
# Quartil 1:  84.0
# Quartil 2:  108.0
# Quartil 3:  129.0
#
#
# Detail kolom  ES DEGAN
# rata-rata:  102.992
# Median:  102.0
# Modus:  ModeResult(mode=array([66]), count=array([11]))
# Standard deviasi:  26.35048265212613
# varian:  0.25584980049058303
# Skewness:  0.059224774215851296
# Quartil 1:  78.75
# Quartil 2:  102.0
# Quartil 3:  125.0
#
#
# Detail kolom  ES KOPYOR
# rata-rata:  105.204
# Median:  106.0
# Modus:  ModeResult(mode=array([131]), count=array([11]))
# Standard deviasi:  26.679325028943293
# varian:  0.2535961087881002
# Skewness:  0.003599489956518007
# Quartil 1:  81.75
# Quartil 2:  106.0
# Quartil 3:  130.0
